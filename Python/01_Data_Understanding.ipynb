# %%
print("E-Commerce Data Analyst Project Started!")
# Out:
# E-Commerce Data Analyst Project Started!

# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from 'c:\\Users\\asus\\AppData\\Local\\Programs\\Python\\Python314\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
df = pd.read_csv("../Data/realistic_e_commerce_sales_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_csv("../Data/realistic_e_commerce_sales_data.csv")
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...

# %%
df = pd.read_csv(
    r"C:\Users\asus\OneDrive\Documents\Ecommerce-Sales-Analytics\Data\realistic_e_commerce_sales_data.csv"
)

# %%
df.head()
# Out:
#   Customer ID  Gender Region   Age Product Name     Category  Unit Price  \
# 0    CUST0268    Male  North   NaN      Monitor  Electronics       300.0
# 1    CUST0046    Male   West  22.0   Headphones  Accessories       100.0
# 2    CUST0169  Female  South  54.0      Monitor  Electronics       300.0
# 3    CUST0002    Male  North  23.0   Headphones  Accessories       100.0
# 4    CUST0173  Female  South   NaN       Laptop  Electronics      1500.0
#
#    Quantity  Total Price  Shipping Fee Shipping Status Order Date
# 0         5         1500         13.31        Returned  12/8/2023
# 1         2          200          6.93      In Transit   4/9/2023
# 2         1          300         11.31        Returned  8/28/2023
# 3         5          500         12.22       Delivered  1/18/2023
# 4         3         4500          5.40       Delivered  1/19/2023

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.columns
# Out:
# Index(['Customer ID', 'Gender', 'Region', 'Age', 'Product Name', 'Category',
#        'Unit Price', 'Quantity', 'Total Price', 'Shipping Fee',
#        'Shipping Status', 'Order Date'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Customer ID      1000 non-null   str
#  1   Gender           1000 non-null   str
#  2   Region           950 non-null    str
#  3   Age              900 non-null    float64
#  4   Product Name     1000 non-null   str
#  5   Category         1000 non-null   str
#  6   Unit Price       1000 non-null   float64
#  7   Quantity         1000 non-null   int64
#  8   Total Price      1000 non-null   int64
#  9   Shipping Fee     1000 non-null   float64
#  10  Shipping Status  950 non-null    str
#  11  Order Date       1000 non-null   str
# dtypes: float64(3), int64(2), str(7)
# memory usage: 93.9 KB

# %%
df.isnull().sum()
# Out:
# Customer ID          0
# Gender               0
# Region              50
# Age                100
# Product Name         0
# Category             0
# Unit Price           0
# Quantity             0
# Total Price          0
# Shipping Fee         0
# Shipping Status     50
# Order Date           0
# dtype: int64

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100

missing_percentage
# Out:
# Customer ID         0.0
# Gender              0.0
# Region              5.0
# Age                10.0
# Product Name        0.0
# Category            0.0
# Unit Price          0.0
# Quantity            0.0
# Total Price         0.0
# Shipping Fee        0.0
# Shipping Status     5.0
# Order Date          0.0
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print("Gender:")
print(df["Gender"].unique())

print("\nRegion:")
print(df["Region"].unique())

print("\nCategory:")
print(df["Category"].unique())

print("\nProduct Name:")
print(df["Product Name"].unique())

print("\nShipping Status:")
print(df["Shipping Status"].unique())
# Out:
# Gender:
# <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str
#
# Region:
# <StringArray>
# ['North', 'West', 'South', 'East', nan]
# Length: 5, dtype: str
#
# Category:
# <StringArray>
# ['Electronics', 'Accessories', 'Wearables']
# Length: 3, dtype: str
#
# Product Name:
# <StringArray>
# [   'Monitor', 'Headphones',     'Laptop', 'Smartwatch',   'Keyboard',
#       'Mouse', 'Smartphone']
# Length: 7, dtype: str
#
# Shipping Status:
# <StringArray>
# ['Returned', 'In Transit', 'Delivered', nan]
# Length: 4, dtype: str

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      524
# Female    476
# Name: count, dtype: int64

# %%
df["Region"].value_counts(dropna=False)
# Out:
# Region
# West     246
# South    244
# East     231
# North    229
# NaN       50
# Name: count, dtype: int64

# %%
df["Category"].value_counts()
# Out:
# Category
# Electronics    477
# Accessories    401
# Wearables      122
# Name: count, dtype: int64

# %%
df["Product Name"].value_counts()
# Out:
# Product Name
# Monitor       181
# Laptop        154
# Keyboard      145
# Smartphone    142
# Mouse         136
# Smartwatch    122
# Headphones    120
# Name: count, dtype: int64

# %%
df["Shipping Status"].value_counts(dropna=False)
# Out:
# Shipping Status
# In Transit    329
# Delivered     313
# Returned      308
# NaN            50
# Name: count, dtype: int64

# %%
df[["Age", "Unit Price", "Quantity", "Total Price", "Shipping Fee"]].describe()
# Out:
#               Age   Unit Price     Quantity  Total Price  Shipping Fee
# count  900.000000  1000.000000  1000.000000  1000.000000   1000.000000
# mean    46.695556   457.703777     3.008000  1346.600000     12.416390
# std     15.011400   537.231434     1.404246  1834.037877      4.412185
# min     18.000000    30.000000     1.000000    30.000000      5.000000
# 25%     35.000000    50.000000     2.000000   200.000000      8.560000
# 50%     49.000000   200.000000     3.000000   600.000000     12.315000
# 75%     59.000000   800.000000     4.000000  1500.000000     16.075000
# max     69.000000  3109.560612     5.000000  7500.000000     19.980000

# %%
df["Order Date"].min(), df["Order Date"].max()
# Out:
# ('1/1/2023', '9/9/2023')

# %%
df["Order Date"].sort_values().tail(10)
# Out:
# 585    9/4/2023
# 289    9/4/2023
# 32     9/5/2023
# 736    9/6/2023
# 649    9/6/2023
# 661    9/6/2023
# 609    9/6/2023
# 292    9/8/2023
# 758    9/9/2023
# 512    9/9/2023
# Name: Order Date, dtype: str

# %%
df["Calculated Total"] = df["Unit Price"] * df["Quantity"]

# %%
df["Difference"] = df["Total Price"] - df["Calculated Total"]

# %%
df["Difference"].value_counts()
# Out:
# Difference
#  0.000000       980
# -214.608082       3
# -1716.864654      2
# -64.382424        2
# -1609.560612      2
# -965.736368       2
# -32.191212        1
# -107.304041       1
# -2575.296981      1
# -8047.803060      1
# -1609.560612      1
# -3219.121224      1
# -160.956061       1
# -643.824245       1
# -6438.242448      1
# Name: count, dtype: int64

# %%
df["Difference"].value_counts()
# Out:
# Difference
#  0.000000       980
# -214.608082       3
# -1716.864654      2
# -64.382424        2
# -1609.560612      2
# -965.736368       2
# -32.191212        1
# -107.304041       1
# -2575.296981      1
# -8047.803060      1
# -1609.560612      1
# -3219.121224      1
# -160.956061       1
# -643.824245       1
# -6438.242448      1
# Name: count, dtype: int64

# %%
df[df["Difference"] != 0]
# Out:
#     Customer ID  Gender Region   Age Product Name     Category   Unit Price  \
# 26     CUST0264    Male   East  59.0   Smartphone  Electronics  1658.432327
# 83     CUST0219    Male    NaN  48.0        Mouse  Accessories    62.191212
# 84     CUST0037    Male   West  51.0     Keyboard  Accessories   103.652020
# 110    CUST0223  Female    NaN  20.0        Mouse  Accessories    62.191212
# 194    CUST0269    Male  North  64.0      Monitor  Electronics   621.912123
# 209    CUST0134    Male  North   NaN      Monitor  Electronics   621.912123
# 215    CUST0194  Female   West  61.0        Mouse  Accessories    62.191212
# 226    CUST0264  Female   West  59.0     Keyboard  Accessories   103.652020
# 244    CUST0128  Female  North  52.0      Monitor  Electronics   621.912123
# 339    CUST0219  Female  South  48.0   Headphones  Accessories   207.304041
# 374    CUST0178  Female  South  44.0   Smartphone  Electronics  1658.432327
# ...

# %%
(df["Difference"] != 0).sum()
# Out:
# np.int64(20)

# %%
error_percentage = (
    (df["Difference"] != 0).sum()
    / len(df)
) * 100

error_percentage
# Out:
# np.float64(2.0)

# %%
(df["Unit Price"] < 0).sum()
# Out:
# np.int64(0)

# %%
(df["Quantity"] <= 0).sum()
# Out:
# np.int64(0)

# %%
(df["Total Price"] < 0).sum()
# Out:
# np.int64(0)

# %%
(df["Shipping Fee"] < 0).sum()
# Out:
# np.int64(0)

# %%
df["Age"].min(), df["Age"].max()
# Out:
# (np.float64(18.0), np.float64(69.0))

# %%
df[(df["Age"] < 18) | (df["Age"] > 100)]
# Out:
# Empty DataFrame
# Columns: [Customer ID, Gender, Region, Age, Product Name, Category, Unit Price, Quantity, Total Price, Shipping Fee, Shipping Status, Order Date, Calculated Total, Difference]
# Index: []

# %%
df["Customer ID"].str.startswith("CUST").value_counts()
# Out:
# Customer ID
# True    1000
# Name: count, dtype: int64

# %%
df["Customer ID"].nunique()
# Out:
# 292

# %%
for col in ["Gender", "Region", "Product Name",
            "Category", "Shipping Status"]:
    print(col, df[col].dropna().str.strip().unique())
# Out:
# Gender <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str
# Region <StringArray>
# ['North', 'West', 'South', 'East']
# Length: 4, dtype: str
# Product Name <StringArray>
# [   'Monitor', 'Headphones',     'Laptop', 'Smartwatch',   'Keyboard',
#       'Mouse', 'Smartphone']
# Length: 7, dtype: str
# Category <StringArray>
# ['Electronics', 'Accessories', 'Wearables']
# Length: 3, dtype: str
# Shipping Status <StringArray>
# ['Returned', 'In Transit', 'Delivered']
# Length: 3, dtype: str

# %%
data_quality = pd.DataFrame({
    "Missing Values": df.isnull().sum(),
    "Missing %": df.isnull().mean() * 100,
    "Unique Values": df.nunique()
})

data_quality
# Out:
#                   Missing Values  Missing %  Unique Values
# Customer ID                    0        0.0            292
# Gender                         0        0.0              2
# Region                        50        5.0              4
# Age                          100       10.0             52
# Product Name                   0        0.0              7
# Category                       0        0.0              3
# Unit Price                     0        0.0             13
# Quantity                       0        0.0              5
# Total Price                    0        0.0             26
# Shipping Fee                   0        0.0            730
# Shipping Status               50        5.0              3
# Order Date                     0        0.0            340
# Calculated Total               0        0.0             40
# Difference                     0        0.0             15

# %%
df["Difference"].value_counts()
# Out:
# Difference
#  0.000000       980
# -214.608082       3
# -1716.864654      2
# -64.382424        2
# -1609.560612      2
# -965.736368       2
# -32.191212        1
# -107.304041       1
# -2575.296981      1
# -8047.803060      1
# -1609.560612      1
# -3219.121224      1
# -160.956061       1
# -643.824245       1
# -6438.242448      1
# Name: count, dtype: int64

# %%
(df["Difference"] != 0).sum()
# Out:
# np.int64(20)

# %%
error_percentage = (
    (df["Difference"] != 0).sum() / len(df)
) * 100

error_percentage
# Out:
# np.float64(2.0)
